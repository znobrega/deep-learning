# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import SGD

# %%
a_data_X = np.array([[0,0],[0,1],[1,0],[1,1]])
a_data_y = np.array([[0],[1],[1],[0]])

train_X, val_X, test_X = a_data_X, a_data_X, a_data_X
train_y, val_y, test_y = a_data_y, a_data_y, a_data_y

# %%
model = Sequential()

model.add(Dense(4, activation='sigmoid')) 
model.add(Dense(1, activation='sigmoid')) 

opt = SGD(learning_rate=0.5, momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['mse', 'acc'])

history = model.fit(train_X, train_y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7872 - mse: 0.2926 - acc: 0.5000
# Epoch 2/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7461 - mse: 0.2749 - acc: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7037 - mse: 0.2551 - acc: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6957 - mse: 0.2513 - acc: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7189 - mse: 0.2626 - acc: 0.5000
# Epoch 6/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7423 - mse: 0.2734 - acc: 0.5000
# Epoch 7/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7428 - mse: 0.2736 - acc: 0.5000
# Epoch 8/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7222 - mse: 0.2641 - acc: 0.5000
# Epoch 9/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6998 - mse: 0.2533 - acc: 0.5000
# ...

# %%
predicted = model.predict(test_X)

print("input | expect | predicted")
for i in range(len(test_X)):
  print(str(test_X[i]) + "    " +str(test_y[i]) +"      " + str(predicted[i]))
# Out:
# input | expect | predicted
# [0 0]    [0]      [0.01339912]
# [0 1]    [1]      [0.9817143]
# [1 0]    [1]      [0.9898038]
# [1 1]    [0]      [0.01527569]

# %%
# Out:
# [[0]
#  [1]
#  [1]
#  [0]]
